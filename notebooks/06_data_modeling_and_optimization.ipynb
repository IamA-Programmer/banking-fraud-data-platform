-- %%
OPTMIZE gold.fraud_transactions;

-- %%
OPTIMIZE gold.fraud_transactions
ZORDER BY (customer_id);

-- %%
VACUUM gold.fraud_trasactions RETAIN 168 HOURS;

-- %%
-- # UPDATE TABLE STATISTICS

ANALYZE TABLE gold.fraud_transactions COMPUTE STATISTICS
